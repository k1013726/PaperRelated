# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/train.csv', index_col=0)
val_df = pd.read_csv('../data/val.csv', index_col=0)
test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Single-step model

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['traffic_volume']) 
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 14

mae_val = [0.083, 0.068, 0.033]
mae_test = [0.081, 0.068, 0.029]

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units=1)
])

history = compile_and_fit(lstm_model, wide_window)

val_performance = {}
performance = {}

val_performance['LSTM'] = lstm_model.evaluate(wide_window.val)
performance['LSTM'] = lstm_model.evaluate(wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 5s 6ms/step - loss: 0.0239 - mean_absolute_error: 0.1114 - val_loss: 0.0094 - val_mean_absolute_error: 0.0699
# Epoch 2/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0575 - val_loss: 0.0046 - val_mean_absolute_error: 0.0482
# Epoch 3/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0043 - mean_absolute_error: 0.0464 - val_loss: 0.0034 - val_mean_absolute_error: 0.0413
# Epoch 4/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0036 - mean_absolute_error: 0.0416 - val_loss: 0.0030 - val_mean_absolute_error: 0.0385
# Epoch 5/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0033 - mean_absolute_error: 0.0393 - val_loss: 0.0027 - val_mean_absolute_error: 0.0363
# Epoch 6/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0031 - mean_absolute_error: 0.0380 - val_loss: 0.0026 - val_mean_absolute_error: 0.0359
# Epoch 7/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0370 - val_loss: 0.0025 - val_mean_absolute_error: 0.0346
# Epoch 8/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0359 - val_loss: 0.0023 - val_mean_absolute_error: 0.0334
# Epoch 9/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0351 - val_loss: 0.0022 - val_mean_absolute_error: 0.0322
# Epoch 10/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0343 - val_loss: 0.0021 - val_mean_absolute_error: 0.0316
# Epoch 11/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0335 - val_loss: 0.0020 - val_mean_absolute_error: 0.0307
# Epoch 12/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0330 - val_loss: 0.0020 - val_mean_absolute_error: 0.0301
# Epoch 13/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0324 - val_loss: 0.0019 - val_mean_absolute_error: 0.0298
# Epoch 14/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0319 - val_loss: 0.0019 - val_mean_absolute_error: 0.0301
# Epoch 15/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0316 - val_loss: 0.0019 - val_mean_absolute_error: 0.0298
# Epoch 16/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0312 - val_loss: 0.0018 - val_mean_absolute_error: 0.0288
# Epoch 17/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0307 - val_loss: 0.0020 - val_mean_absolute_error: 0.0315
# Epoch 18/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0305 - val_loss: 0.0017 - val_mean_absolute_error: 0.0278
# Epoch 19/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0302 - val_loss: 0.0017 - val_mean_absolute_error: 0.0277
# Epoch 20/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0301 - val_loss: 0.0017 - val_mean_absolute_error: 0.0276
# Epoch 21/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0020 - mean_absolute_error: 0.0298 - val_loss: 0.0017 - val_mean_absolute_error: 0.0285
# Epoch 22/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0020 - mean_absolute_error: 0.0297 - val_loss: 0.0016 - val_mean_absolute_error: 0.0277
# Epoch 23/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0020 - mean_absolute_error: 0.0293 - val_loss: 0.0016 - val_mean_absolute_error: 0.0272
# Epoch 24/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0020 - mean_absolute_error: 0.0293 - val_loss: 0.0016 - val_mean_absolute_error: 0.0267
# Epoch 25/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0291 - val_loss: 0.0016 - val_mean_absolute_error: 0.0269
# Epoch 26/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0289 - val_loss: 0.0017 - val_mean_absolute_error: 0.0284
# Epoch 27/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0288 - val_loss: 0.0015 - val_mean_absolute_error: 0.0269
# Epoch 28/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0286 - val_loss: 0.0015 - val_mean_absolute_error: 0.0272
# Epoch 29/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0285 - val_loss: 0.0015 - val_mean_absolute_error: 0.0259
# Epoch 30/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0282 - val_loss: 0.0015 - val_mean_absolute_error: 0.0260
# Epoch 31/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0282 - val_loss: 0.0015 - val_mean_absolute_error: 0.0260
# Epoch 32/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0281 - val_loss: 0.0015 - val_mean_absolute_error: 0.0268
# Epoch 33/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0280 - val_loss: 0.0015 - val_mean_absolute_error: 0.0263
# Epoch 34/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0279 - val_loss: 0.0016 - val_mean_absolute_error: 0.0278
# 109/109 [==============================] - 0s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0278

# %%
wide_window.plot(lstm_model)

plt.savefig('figures/CH15_F09_peixeiro.png', dpi=300)

# %%
mae_val.append(val_performance['LSTM'][1])
mae_test.append(performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH15_F10_peixeiro.png', dpi=300)

# %% [markdown]
# ### Multi-step model

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 14

ms_mae_val = [0.352, 0.347, 0.088, 0.078]
ms_mae_test = [0.347, 0.341, 0.076, 0.064]

# %%
ms_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_lstm_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.val)
ms_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 4s 6ms/step - loss: 0.0425 - mean_absolute_error: 0.1465 - val_loss: 0.0199 - val_mean_absolute_error: 0.0995
# Epoch 2/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0161 - mean_absolute_error: 0.0886 - val_loss: 0.0176 - val_mean_absolute_error: 0.0923
# Epoch 3/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0145 - mean_absolute_error: 0.0817 - val_loss: 0.0159 - val_mean_absolute_error: 0.0831
# Epoch 4/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0138 - mean_absolute_error: 0.0791 - val_loss: 0.0159 - val_mean_absolute_error: 0.0801
# Epoch 5/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0134 - mean_absolute_error: 0.0771 - val_loss: 0.0152 - val_mean_absolute_error: 0.0837
# Epoch 6/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0130 - mean_absolute_error: 0.0759 - val_loss: 0.0148 - val_mean_absolute_error: 0.0782
# Epoch 7/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0129 - mean_absolute_error: 0.0752 - val_loss: 0.0141 - val_mean_absolute_error: 0.0781
# Epoch 8/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0745 - val_loss: 0.0141 - val_mean_absolute_error: 0.0793
# Epoch 9/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0125 - mean_absolute_error: 0.0736 - val_loss: 0.0140 - val_mean_absolute_error: 0.0778
# Epoch 10/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0123 - mean_absolute_error: 0.0729 - val_loss: 0.0141 - val_mean_absolute_error: 0.0804
# Epoch 11/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0122 - mean_absolute_error: 0.0724 - val_loss: 0.0137 - val_mean_absolute_error: 0.0753
# Epoch 12/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0120 - mean_absolute_error: 0.0718 - val_loss: 0.0137 - val_mean_absolute_error: 0.0770
# Epoch 13/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0118 - mean_absolute_error: 0.0710 - val_loss: 0.0133 - val_mean_absolute_error: 0.0736
# Epoch 14/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0115 - mean_absolute_error: 0.0699 - val_loss: 0.0129 - val_mean_absolute_error: 0.0754
# Epoch 15/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0113 - mean_absolute_error: 0.0693 - val_loss: 0.0129 - val_mean_absolute_error: 0.0715
# Epoch 16/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0111 - mean_absolute_error: 0.0683 - val_loss: 0.0125 - val_mean_absolute_error: 0.0712
# Epoch 17/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0109 - mean_absolute_error: 0.0674 - val_loss: 0.0125 - val_mean_absolute_error: 0.0693
# Epoch 18/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0108 - mean_absolute_error: 0.0667 - val_loss: 0.0126 - val_mean_absolute_error: 0.0717
# Epoch 19/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0107 - mean_absolute_error: 0.0664 - val_loss: 0.0121 - val_mean_absolute_error: 0.0690
# Epoch 20/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0106 - mean_absolute_error: 0.0659 - val_loss: 0.0121 - val_mean_absolute_error: 0.0686
# Epoch 21/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0104 - mean_absolute_error: 0.0654 - val_loss: 0.0122 - val_mean_absolute_error: 0.0707
# Epoch 22/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0103 - mean_absolute_error: 0.0647 - val_loss: 0.0122 - val_mean_absolute_error: 0.0724
# Epoch 23/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0103 - mean_absolute_error: 0.0647 - val_loss: 0.0118 - val_mean_absolute_error: 0.0672
# Epoch 24/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0102 - mean_absolute_error: 0.0640 - val_loss: 0.0116 - val_mean_absolute_error: 0.0669
# Epoch 25/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0101 - mean_absolute_error: 0.0636 - val_loss: 0.0116 - val_mean_absolute_error: 0.0667
# Epoch 26/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0633 - val_loss: 0.0116 - val_mean_absolute_error: 0.0667
# Epoch 27/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0099 - mean_absolute_error: 0.0632 - val_loss: 0.0118 - val_mean_absolute_error: 0.0661
# Epoch 28/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0098 - mean_absolute_error: 0.0627 - val_loss: 0.0115 - val_mean_absolute_error: 0.0659
# Epoch 29/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0626 - val_loss: 0.0114 - val_mean_absolute_error: 0.0660
# Epoch 30/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0097 - mean_absolute_error: 0.0624 - val_loss: 0.0119 - val_mean_absolute_error: 0.0704
# Epoch 31/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0096 - mean_absolute_error: 0.0620 - val_loss: 0.0113 - val_mean_absolute_error: 0.0682
# Epoch 32/50
# 383/383 [==============================] - 3s 9ms/step - loss: 0.0095 - mean_absolute_error: 0.0615 - val_loss: 0.0115 - val_mean_absolute_error: 0.0660
# Epoch 33/50
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0094 - mean_absolute_error: 0.0614 - val_loss: 0.0114 - val_mean_absolute_error: 0.0653
# Epoch 34/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0094 - mean_absolute_error: 0.0614 - val_loss: 0.0112 - val_mean_absolute_error: 0.0663
# Epoch 35/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0608 - val_loss: 0.0113 - val_mean_absolute_error: 0.0648
# Epoch 36/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0608 - val_loss: 0.0111 - val_mean_absolute_error: 0.0659
# Epoch 37/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0607 - val_loss: 0.0111 - val_mean_absolute_error: 0.0683
# Epoch 38/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0603 - val_loss: 0.0111 - val_mean_absolute_error: 0.0660
# Epoch 39/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0601 - val_loss: 0.0113 - val_mean_absolute_error: 0.0650
# 109/109 [==============================] - 0s 2ms/step - loss: 0.0113 - mean_absolute_error: 0.0650

# %%
multi_window.plot(ms_lstm_model)

plt.savefig('figures/CH15_F11_peixeiro.png', dpi=300)

# %%
ms_mae_val.append(ms_val_performance['LSTM'][1])
ms_mae_test.append(ms_performance['LSTM'][1])

x = np.arange(5)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH15_F12_peixeiro.png', dpi=300)

# %% [markdown]
# ### Multi-output model

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['temp','traffic_volume']) 
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['temp','traffic_volume'])

# %%
# Values from chapter 14

mo_mae_val = [0.048, 0.039, 0.023]
mo_mae_test = [0.047, 0.036, 0.020]

# %%
mo_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units = 2)
])

history = compile_and_fit(mo_lstm_model, mo_wide_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.val)
mo_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 4s 6ms/step - loss: 0.0209 - mean_absolute_error: 0.0952 - val_loss: 0.0081 - val_mean_absolute_error: 0.0573
# Epoch 2/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0050 - mean_absolute_error: 0.0449 - val_loss: 0.0034 - val_mean_absolute_error: 0.0369
# Epoch 3/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0359 - val_loss: 0.0026 - val_mean_absolute_error: 0.0331
# Epoch 4/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0326 - val_loss: 0.0021 - val_mean_absolute_error: 0.0302
# Epoch 5/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0300 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
# Epoch 6/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0281 - val_loss: 0.0017 - val_mean_absolute_error: 0.0268
# Epoch 7/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0269 - val_loss: 0.0016 - val_mean_absolute_error: 0.0249
# Epoch 8/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0259 - val_loss: 0.0015 - val_mean_absolute_error: 0.0248
# Epoch 9/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0251 - val_loss: 0.0015 - val_mean_absolute_error: 0.0246
# Epoch 10/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0014 - val_mean_absolute_error: 0.0233
# Epoch 11/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0240 - val_loss: 0.0013 - val_mean_absolute_error: 0.0226
# Epoch 12/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0235 - val_loss: 0.0013 - val_mean_absolute_error: 0.0221
# Epoch 13/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0232 - val_loss: 0.0013 - val_mean_absolute_error: 0.0227
# Epoch 14/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0229 - val_loss: 0.0012 - val_mean_absolute_error: 0.0216
# Epoch 15/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0226 - val_loss: 0.0012 - val_mean_absolute_error: 0.0215
# Epoch 16/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0223 - val_loss: 0.0012 - val_mean_absolute_error: 0.0216
# Epoch 17/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0221 - val_loss: 0.0011 - val_mean_absolute_error: 0.0205
# Epoch 18/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0219 - val_loss: 0.0011 - val_mean_absolute_error: 0.0205
# Epoch 19/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0217 - val_loss: 0.0011 - val_mean_absolute_error: 0.0209
# Epoch 20/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0216 - val_loss: 0.0011 - val_mean_absolute_error: 0.0202
# Epoch 21/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0214 - val_loss: 0.0010 - val_mean_absolute_error: 0.0199
# Epoch 22/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0213 - val_loss: 0.0010 - val_mean_absolute_error: 0.0197
# Epoch 23/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0212 - val_loss: 0.0011 - val_mean_absolute_error: 0.0212
# Epoch 24/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0210 - val_loss: 0.0010 - val_mean_absolute_error: 0.0201
# Epoch 25/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0209 - val_loss: 0.0010 - val_mean_absolute_error: 0.0201
# Epoch 26/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0208 - val_loss: 9.4450e-04 - val_mean_absolute_error: 0.0191
# Epoch 27/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0208 - val_loss: 9.4936e-04 - val_mean_absolute_error: 0.0194
# Epoch 28/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0206 - val_loss: 9.8080e-04 - val_mean_absolute_error: 0.0198
# Epoch 29/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0206 - val_loss: 9.5873e-04 - val_mean_absolute_error: 0.0195
# 109/109 [==============================] - 0s 2ms/step - loss: 9.5873e-04 - mean_absolute_error: 0.0195

# %%
mo_wide_window.plot(mo_lstm_model)

plt.savefig('figures/CH15_F13_peixeiro.png', dpi=300)

# %%
mo_wide_window.plot(model=mo_lstm_model, plot_col='temp')

plt.savefig('figures/CH15_F14_peixeiro.png', dpi=300)

# %%
mo_mae_val.append(mo_val_performance['LSTM'][1])
mo_mae_test.append(mo_performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH15_F15_peixeiro.png', dpi=300)
